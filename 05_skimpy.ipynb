# %% [markdown]
# # How to do skiming of the data?

# %%
! pip install skimpy
# Out:
# ...
#   Using cached skimpy-0.0.11-py3-none-any.whl.metadata (36 kB)
# ...
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# ...
#   Using cached polars-0.19.14-cp38-abi3-win_amd64.whl.metadata (15 kB)
# ...
#   Using cached pyarrow-13.0.0.tar.gz (1.0 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached rich-13.7.0-py3-none-any.whl.metadata (18 kB)
# ...
#   Using cached typeguard-4.1.4-py3-none-any.whl.metadata (3.7 kB)
# ...
#   Using cached notebook-7.0.6-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached qtconsole-5.5.1-py3-none-any.whl.metadata (5.1 kB)
# ...
#   Using cached jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# ...

# %%
# import libries
import pandas as pd
import seaborn as sns
from skimpy import skim
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\santosh\Desktop\.conda\Python_For_Data_Science\Data analysis\05_skimpy.ipynb Cell 3 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/santosh/Desktop/.conda/Python_For_Data_Science/Data%20analysis/05_skimpy.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> import pandas as pd
#       <a href='vscode-notebook-cell:/c%3A/Users/santosh/Desktop/.conda/Python_For_Data_Science/Data%20analysis/05_skimpy.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> import seaborn as sns
# ----> <a href='vscode-notebook-cell:/c%3A/Users/santosh/Desktop/.conda/Python_For_Data_Science/Data%20analysis/05_skimpy.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> from skimpy import skim
#
# ModuleNotFoundError: No module named 'skimpy'

# %%
df = pd.read_csv(".conda/Python_For_Data_Science/Data analysis/googleplaystore.csv.zip")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\santosh\Desktop\.conda\Python_For_Data_Science\Data analysis\05_skimpy.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/santosh/Desktop/.conda/Python_For_Data_Science/Data%20analysis/05_skimpy.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> df = pd.read_csv(".conda/Python_For_Data_Science/Data analysis/googleplaystore.csv.zip")
#
# ...
